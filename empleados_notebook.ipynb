# %% [markdown]
# # No hay acceso
#
# Este cuaderno está restringido. Por favor, contacte al administrador para solicitar acceso.

# %%
import ipywidgets as widgets
from IPython.display import display, Markdown

# Crear contenido para cada pestaña
cv_content = widgets.Output()
habilidades_content = widgets.Output()

with cv_content:
    display(Markdown("""
### Currículum Vitae (CV)

Aquí puedes agregar o visualizar el CV del empleado.
"""))

with habilidades_content:
    display(Markdown("""
### Habilidades

Aquí puedes agregar o visualizar las habilidades del empleado.
"""))

# Crear las pestañas
pestanas = widgets.Tab(children=[cv_content, habilidades_content])
pestanas.set_title(0, 'CV')
pestanas.set_title(1, 'Habilidades')

# Mostrar las pestañas
pestanas
